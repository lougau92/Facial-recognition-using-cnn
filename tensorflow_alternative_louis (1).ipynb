# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
import torchvision
import torch
from tensorflow.keras.models import Model
from sklearn.model_selection import KFold
import warnings
warnings.filterwarnings("ignore")


from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
emotion_dict = {0:'anger', 1:'disgust', 2:'fear', 3:'happiness', 4: 'sadness', 5: 'surprise', 6: 'neutral'}

def one_hot_encoder(label:int, num_labels:int) -> np.ndarray:
    """Takes a numeric label value and returns the corresponding one-hot-encoding vector given the number of labels.
    Labels need to start from zero with step size 1.
    Example: if there are label {0,1,2}, so num_labels=3. Then the method will transform {1} into [0,1,0].
    Example: if there are labels {0,5,9} the method will not work as the labels do not have step size 1 between them.

    Args:
        label (int): label to be transformed into a one-hot-encoding vector
        num_labels (int): number of labels in total

    Returns:
        np.ndarray: one-hot-encoding vector
    """    
    one_hot_vector = np.zeros(num_labels)
    one_hot_vector[label] = 1
    return one_hot_vector

# %%
# path = 'C:/Users/louis/github_vs/archive/fer2013/fer2013/fer2013.csv'
path = '/content/drive/MyDrive/DKE/fer2013/fer2013.csv'
df = pd.read_csv(path)
num_emotions = df.emotion.value_counts().shape[0]

df_train = df[df['Usage']=='Training'].drop(labels=['Usage'], axis=1)
df_val = df[df['Usage']=='PublicTest'].drop(labels=['Usage'], axis=1)
df_test = df[df['Usage']=='PrivateTest'].drop(labels=['Usage'], axis=1)

X_train = df_train.pixels.apply(lambda x: np.array(x.split(' ')).reshape(48, 48, 1).astype('float32'))
X_train = np.stack(X_train, axis=0)/255
y_train = df_train.emotion.apply(lambda x: one_hot_encoder(x, num_labels=num_emotions))
y_train = np.stack(y_train, axis=0)
X_val = df_val.pixels.apply(lambda x: np.array(x.split(' ')).reshape(48, 48, 1).astype('float32'))
X_val = np.stack(X_val, axis=0)/255
y_val = df_val.emotion.apply(lambda x: one_hot_encoder(x, num_labels=num_emotions))
y_val = np.stack(y_val, axis=0)
X_test = df_test.pixels.apply(lambda x: np.array(x.split(' ')).reshape(48, 48, 1).astype('float32'))
X_test = np.stack(X_test, axis=0)/255
y_test = df_test.emotion.apply(lambda x: one_hot_encoder(x, num_labels=num_emotions))
y_test = np.stack(y_test, axis=0)

X = np.concatenate((X_train,X_val),axis=0)
y = np.concatenate((y_train,y_val),axis=0)

print(f'Shape of X_train, y_train: {X_train.shape}, {y_train.shape}')
print(f'Shape of X_val, y_val: {X_val.shape}, {y_val.shape}')
print(f'Shape of X_test, y_test: {X_test.shape}, {y_test.shape}', end='')
# Out:
# Shape of X_train, y_train: (28709, 48, 48, 1), (28709, 7)
# Shape of X_val, y_val: (3589, 48, 48, 1), (3589, 7)
# Shape of X_test, y_test: (3589, 48, 48, 1), (3589, 7)

# %%
# decided to use the pytorch RandAugment() method as it does exactly what we want
def augment_image(image:np.ndarray):
    prob_for_augmentation = 0.1
    if np.random.random() < prob_for_augmentation:
        transform = torchvision.transforms.Compose([
            torchvision.transforms.ToTensor(),
            torchvision.transforms.ConvertImageDtype(dtype=torch.uint8),
            torchvision.transforms.RandAugment()
        ])
        augmented_image = transform((image*255).astype(np.uint8))
        return np.rollaxis(augmented_image.numpy(), axis=0, start=3)/255
    else: return image

image_augmenter = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=augment_image)

# testing to see what outputs the augment_image method returns
# on average, one for every (1/prob_for_augmentation) images will be transformed
fig = plt.figure(figsize=(18, 32))
for i in range(40):
    ax = plt.subplot(8, 5, i+1)
    ax.imshow(augment_image(X_train[10]).reshape(48,48), cmap='gray')
    ax.set_xticks([])
    ax.set_yticks([])
plt.tight_layout()

# alternative ImageDataGenerator function implemented in TensorFlow. 
# I don't like it as much as it does not let you control how many images are augmented. All images are augmented every epoch, which is not what we want I think.
# testing how the augmentations produced by ImageDataGenerator look like
# image_augmenter = tf.keras.preprocessing.image.ImageDataGenerator(vertical_flip=True, horizontal_flip=True, rotation_range=20, width_shift_range=0.1, height_shift_range=0.1, zoom_range=0.1, shear_range=10, rescale=1/255.)
# image_augmenter.fit(X_train)
# test = image_augmenter.random_transform(X_train[10])
# plt.imshow(test, cmap='gray')
# print(test.shape)

# %% [markdown]
# Emotion encoding:
# - 0: anger
# - 1: disgust
# - 2: fear
# - 3: happiness
# - 4: sadness
# - 5: surprise
# - 6: neutral

# %%
def create_model(**kwargs) -> tf.keras.Model:
    """creates a keras model which has the architecture pre-specified. 
    The hyperparameters for the model can be passed as keyword arguments and will be used by the model.
    Which parameters can be specified as keyword arguments can be inferred from the "params" dictionary declared in this method.
    In order to adapt for entirely different archtictures, you might want to add further items to the "params" dictionary to allow
    the method to specify the additional (or new) hyper parameters.

    Returns:
        tf.keras.Model: compiled keras model
    """    
    # define default parameter values if not otherwise specified through inputs
    params={'learning_rate': 0.005, 
            'num_convBlocks': 2, 'filters': [64, 64], 'kernel_sizes': [3, 3], 'strides': [(1,1), (1,1)], 'pool_sizes': [(3,3), (3,3)],
            'dense_units': 16, 'dropout': 0}
    for key, value in kwargs.items():
        if key in params:
            params[key] = value

    assert params['num_convBlocks'] >= 1, 'Model needs to have at least one convolutional block to work.'
    assert (params['num_convBlocks'] == len(params['filters'])) & \
            (params['num_convBlocks'] == len(params['kernel_sizes'])) & \
            (params['num_convBlocks'] == len(params['strides'])) & \
            (params['num_convBlocks'] == len(params['pool_sizes'])), 'Specified number of convolutional blocks does not match the number of parameters.'

    model = keras.models.Sequential()

    model.add(keras.layers.Conv2D(filters=params['filters'][0], kernel_size=params['kernel_sizes'][0],
                                    strides=params['strides'][0], activation='relu', input_shape=(48,48,1), data_format='channels_last'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.MaxPool2D(pool_size=params['pool_sizes'][0]))

    for i in range(params['num_convBlocks']-1):
        model.add(keras.layers.Conv2D(filters=params['filters'][i+1], kernel_size=params['kernel_sizes'][i+1], strides=params['strides'][i+1], activation='relu'))
        model.add(keras.layers.MaxPool2D(pool_size=params['pool_sizes'][i+1]))
        model.add(keras.layers.BatchNormalization())

    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(units=params['dense_units'], activation='relu'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Dropout(rate=params['dropout']))
    model.add(keras.layers.Dense(units=7, activation='softmax'))

    optimizer = tf.keras.optimizers.Adam(learning_rate=params['learning_rate'])
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    model.summary()

    return model

# early stopping might need adaptation depending on how the convergence behavior of the model
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=4, verbose=1, restore_best_weights=True)

def train_model(epochs:int=100, batch_size:int=15, plot_loss:bool=True, run_on_mac:bool=False, data = [X_train,y_train,X_val,y_val,X_test,y_test],**kwargs):
    """Trains a keras model with architecture specified in the create_model() method.
    Values for hyper parameters that should be used to build the model can be passed as keyword arguments
    or as a dictionary (compare create_model() method to see which ones are available).
    Parameters for the training of the model can be passed directly as inputs to this method.

    Args:
        epochs (int, optional): Maximum number of epochs to train, if early stopping does not cause earlier termination. Defaults to 500.
        batch_size (int, optional): size of a single batch. Defaults to 64.
        plot_loss (bool, optional): whether or not to plot a loss curve at the end of training. Defaults to True.
        run_on_mac (bool, optional): only set to true if you are using a mac and want to utilize its CPU instead of GPU. Defaults to False.

    Returns:
        tf.keras.Model, tf.keras.callbacks.History: returns the trained model and the training history
    """  

    model_params = ['learning_rate', 'filters1', 'filters2', 'kernel_size1', 'kernel_size2', 'strides1', 'strides2', 'dense_units', 'pool_size1', 'pool_size2', 'dropout']
    model_kwargs = {}
    for key, value in kwargs.items():
        if key in model_params:
            model_kwargs[key] = value
    
    model = create_model(**model_kwargs)

  

    image_augmenter = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=augment_image)
    image_augmenter.fit(X_train)

    if run_on_mac:
        with tf.device('/cpu:0'): # only added this because the code runs quicker on my cpu than on my gpu
            history = model.fit(
                    image_augmenter.flow(data[0], data[1], batch_size=batch_size), 
                    validation_data=(data[2], data[3]), 
                    # steps_per_epoch=len(data[0])//batch_size,
                     epochs=epochs,
                    # validation_steps = len(data[2])//batch_size, 
                    callbacks=[early_stopping], use_multiprocessing=False
                )
    else:
            history = model.fit(
                    image_augmenter.flow(data[0], data[1], batch_size=batch_size), 
                    validation_data=(data[2], data[3]), 
                    # steps_per_epoch=len(data[0])//batch_size,
                    # validation_steps = len(data[2])//batch_size,
                     epochs=epochs, 
                    callbacks=[early_stopping], use_multiprocessing=False
                )

    if plot_loss:
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'], '--')
        plt.title('model loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'validation'], loc='upper right')
        plt.show()

    test_accuracy = np.round(model.evaluate(x=data[4], y=data[5], workers=12, use_multiprocessing=False, verbose=0)[1], 6)
    print(f'Accuracy on test set: {test_accuracy}')

    return model, history

# %%
for layer in model.layers:
        print(layer)
        try:
                weights_n = layer.get_weights()[0] #WHY are the weights for dimentional? -> how  do we print the (3,3,64,64) weights?
                print(weights_n.shape)
        except:
                weights_n = []
                print(layer.get_weights())
# Out:
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000002340988C9A0>
# (3, 3, 1, 64)
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000002340A381CD0>
# (64,)
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x000002340985F220>
# []
# <keras.layers.convolutional.conv2d.Conv2D object at 0x0000023409DFF0A0>
# (3, 3, 64, 64)
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x00000234099241F0>
# []
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x0000023409954310>
# (64,)
# <keras.layers.reshaping.flatten.Flatten object at 0x0000023409DF1550>
# []
# <keras.layers.core.dense.Dense object at 0x00000234099736D0>
# (1024, 16)
# <keras.layers.regularization.dropout.Dropout object at 0x0000023409982BE0>
# []
# <keras.layers.core.dense.Dense object at 0x0000023409967850>
# (16, 7)

# %%
# print the layer weights of the model
for layer in model.layers:
    if 'conv' in layer.name: # do with also have to do the maxpooling layers?
        fig = plt.figure(figsize=(30,30))

        weights_n = layer.get_weights()[0]
        plt.title(str("layer "+layer.__str__()+weights_n.shape.__str__()))
        size = np.ceil(np.sqrt(weights_n.shape[3])) # size of the grid
        for filter in range(weights_n.shape[3]):
            fig.add_subplot(size,size,filter+1)
            plt.imshow(weights_n[:,:,0,filter], cmap='gray') # are there 3x3 filters of 64/ or 64 times 3x3 filters?
            plt.axis('off')

# %%
# getting the activations of layers for a given image (so that we can test and compare for the different classes)
def plot_filters(model, img):
    for layer in model.layers:
            modelLayer = Model(inputs=model.inputs, outputs=model.get_layer(layer.name).output).predict(img) # get the activations of the 'outputs' layer
            if(len(modelLayer.shape)>2): # do not print the last prediction layer (not a convolution layer)
                fig = plt.figure(figsize=(30,30))
                plt.title(str(layer.name+" "+str(modelLayer.shape)))
                size = np.ceil(np.sqrt(modelLayer.shape[3]))
                for filter in range(modelLayer.shape[3]):
                    fig.add_subplot(size,size,filter+1)
                    plt.imshow(modelLayer[0,:,:,filter], cmap='gray')
                    plt.axis('off')      
print("label = ",emotion_dict[np.argmax(y_test[0])])      
plot_filters(model, np.expand_dims(X_test[0],axis=0))
# Out:
# label =  anger
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step

# %%
# parameter tuning experiments: all the different parameters to be tested
lrs = [0.001,0.005,0.007,0.01,0.05]
pool_sizes = [2,3,4,5,6,7,8]
filter_sizes = [3,5,10,15,20]
stride_sizes = [1,2,3,4,5]
order = [2,4,6,8]
dropout_rates = [0.2,0.4,0.6,0.8]
scalers = [4,8,16,32,65]

# %%
# model_params = ['learning_rate', 'filters1', 'filters2', 'kernel_size1', 'kernel_size2', 'strides1', 'strides2', 'dense_units', 'pool_size1', 'pool_size2', 'dropout']

def run_experiment(param_name,param_set,x_sigmoid=False):
    num_folds = 4
    metrics_means = []; metrics_std = []
    for param in param_set:
        kfold = KFold(n_splits=num_folds, shuffle=True)

        print(param_name," = ",param)
        metrics =[];
        for train, test in kfold.split(X, y):
    
            model, history = train_model(epochs = 15,plot_loss=False, data = [X[train],y[train],X[test],y[test],X_test,y_test], param_name=param)
            test_accuracy = np.round(model.evaluate(x=X_test, y=y_test, workers=12, use_multiprocessing=False, verbose=0)[1], 6)   
            metrics.append(test_accuracy)
        metrics_means.append(np.mean(metrics))
        metrics_std.append(np.std(metrics))

    figure = plt.figure(figsize=(10,10))
    plt.errorbar(param_set,metrics_means,yerr=metrics_std,fmt='-o',ecolor='r',capsize=5)
    
    if x_sigmoid: plt.semilogx()
    plt.title(str('Validation Accuracy Score vs '+param_name))
    plt.xlabel(param_name)
    plt.ylabel("Validation Accuracy Score")

# %%
run_experiment('learning_rate',lrs,x_sigmoid=True)
# [0.556422,0.534689,0.545277,0.526888]
#  [0.556422,]
# Out:
# learning_rate  =  0.001
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 64)        640
#
#  batch_normalization (BatchN  (None, 46, 46, 64)       256
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 4, 4, 64)         256
#  hNormalization)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 16)                16400
#
#  batch_normalization_2 (Batc  (None, 16)               64
#  hNormalization)
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense_1 (Dense)             (None, 7)                 119
#
# =================================================================
# Total params: 54,663
# Trainable params: 54,375
# Non-trainable params: 288
# _________________________________________________________________
# Epoch 1/15
# 1615/1615 [==============================] - 25s 7ms/step - loss: 1.5854 - accuracy: 0.3807 - val_loss: 1.4676 - val_accuracy: 0.4196
# Epoch 2/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.4077 - accuracy: 0.4598 - val_loss: 1.6351 - val_accuracy: 0.4222
# Epoch 3/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.3379 - accuracy: 0.4882 - val_loss: 1.4385 - val_accuracy: 0.4586
# Epoch 4/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.2913 - accuracy: 0.5115 - val_loss: 1.4053 - val_accuracy: 0.4772
# Epoch 5/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.3696 - accuracy: 0.4781 - val_loss: 1.4566 - val_accuracy: 0.4661
# Epoch 6/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.2783 - accuracy: 0.5180 - val_loss: 1.3319 - val_accuracy: 0.5012
# Epoch 7/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.2470 - accuracy: 0.5326 - val_loss: 1.3933 - val_accuracy: 0.4604
# Epoch 8/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.2171 - accuracy: 0.5402 - val_loss: 1.3309 - val_accuracy: 0.4925
# Epoch 9/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.2083 - accuracy: 0.5452 - val_loss: 1.5153 - val_accuracy: 0.4554
# Epoch 10/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.1731 - accuracy: 0.5584 - val_loss: 1.3041 - val_accuracy: 0.5105
# Epoch 11/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.1522 - accuracy: 0.5639 - val_loss: 1.3991 - val_accuracy: 0.4708
# Epoch 12/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.1373 - accuracy: 0.5721 - val_loss: 1.3094 - val_accuracy: 0.5258
# Epoch 13/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.1206 - accuracy: 0.5789 - val_loss: 1.2747 - val_accuracy: 0.5250
# Epoch 14/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.1044 - accuracy: 0.5848 - val_loss: 1.2855 - val_accuracy: 0.5200
# Epoch 15/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.0831 - accuracy: 0.5915 - val_loss: 1.2873 - val_accuracy: 0.5290
# Accuracy on test set: 0.529953
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 46, 46, 64)        640
#
#  batch_normalization_3 (Batc  (None, 46, 46, 64)       256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 15, 15, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 4, 4, 64)         256
#  hNormalization)
#
#  flatten_1 (Flatten)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 16)                16400
#
#  batch_normalization_5 (Batc  (None, 16)               64
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_3 (Dense)             (None, 7)                 119
#
# =================================================================
# Total params: 54,663
# Trainable params: 54,375
# Non-trainable params: 288
# _________________________________________________________________
# Epoch 1/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.5565 - accuracy: 0.3959 - val_loss: 1.4431 - val_accuracy: 0.4448
# Epoch 2/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.3854 - accuracy: 0.4725 - val_loss: 1.3341 - val_accuracy: 0.4928
# Epoch 3/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.3040 - accuracy: 0.5077 - val_loss: 1.4136 - val_accuracy: 0.4542
# Epoch 4/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.2476 - accuracy: 0.5271 - val_loss: 1.5049 - val_accuracy: 0.4277
# Epoch 5/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.2248 - accuracy: 0.5366 - val_loss: 1.6904 - val_accuracy: 0.4233
# Epoch 6/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.1779 - accuracy: 0.5553 - val_loss: 1.2955 - val_accuracy: 0.4946
# Epoch 7/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.1470 - accuracy: 0.5687 - val_loss: 1.2794 - val_accuracy: 0.5172
# Epoch 8/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.1198 - accuracy: 0.5813 - val_loss: 1.4994 - val_accuracy: 0.4559
# Epoch 9/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.0911 - accuracy: 0.5892 - val_loss: 1.3258 - val_accuracy: 0.4959
# Epoch 10/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.0670 - accuracy: 0.6005 - val_loss: 1.3393 - val_accuracy: 0.5030
# Epoch 11/15
# 1615/1615 [==============================] - ETA: 0s - loss: 1.0462 - accuracy: 0.6063Restoring model weights from the end of the best epoch: 7.
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.0462 - accuracy: 0.6063 - val_loss: 1.2964 - val_accuracy: 0.5111
# Epoch 11: early stopping
# Accuracy on test set: 0.527445
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 46, 46, 64)        640
#
#  batch_normalization_6 (Batc  (None, 46, 46, 64)       256
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 15, 15, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  batch_normalization_7 (Batc  (None, 4, 4, 64)         256
#  hNormalization)
#
#  flatten_2 (Flatten)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 16)                16400
#
#  batch_normalization_8 (Batc  (None, 16)               64
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  dense_5 (Dense)             (None, 7)                 119
#
# =================================================================
# Total params: 54,663
# Trainable params: 54,375
# Non-trainable params: 288
# _________________________________________________________________
# Epoch 1/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.5948 - accuracy: 0.3786 - val_loss: 1.7034 - val_accuracy: 0.4008
# Epoch 2/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.4124 - accuracy: 0.4568 - val_loss: 1.6136 - val_accuracy: 0.4550
# Epoch 3/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.3420 - accuracy: 0.4884 - val_loss: 1.3824 - val_accuracy: 0.4711
# Epoch 4/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.2886 - accuracy: 0.5127 - val_loss: 1.5226 - val_accuracy: 0.4326
# Epoch 5/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.2553 - accuracy: 0.5215 - val_loss: 1.2535 - val_accuracy: 0.5277
# Epoch 6/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.2230 - accuracy: 0.5450 - val_loss: 2.4272 - val_accuracy: 0.3857
# Epoch 7/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.1942 - accuracy: 0.5495 - val_loss: 1.3210 - val_accuracy: 0.5001
# Epoch 8/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.1684 - accuracy: 0.5608 - val_loss: 1.2687 - val_accuracy: 0.5213
# Epoch 9/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.1440 - accuracy: 0.5712 - val_loss: 1.2421 - val_accuracy: 0.5290
# Epoch 10/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.1255 - accuracy: 0.5836 - val_loss: 1.3677 - val_accuracy: 0.5048
# Epoch 11/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.1059 - accuracy: 0.5842 - val_loss: 1.3193 - val_accuracy: 0.5217
# Epoch 12/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.0866 - accuracy: 0.5937 - val_loss: 1.3032 - val_accuracy: 0.5186
# Epoch 13/15
# 1611/1615 [============================>.] - ETA: 0s - loss: 1.0746 - accuracy: 0.6013Restoring model weights from the end of the best epoch: 9.
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.0746 - accuracy: 0.6012 - val_loss: 1.2429 - val_accuracy: 0.5324
# Epoch 13: early stopping
# Accuracy on test set: 0.526052
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 46, 46, 64)        640
#
#  batch_normalization_9 (Batc  (None, 46, 46, 64)       256
#  hNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 15, 15, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_7 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  batch_normalization_10 (Bat  (None, 4, 4, 64)         256
#  chNormalization)
#
#  flatten_3 (Flatten)         (None, 1024)              0
#
#  dense_6 (Dense)             (None, 16)                16400
#
#  batch_normalization_11 (Bat  (None, 16)               64
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 16)                0
#
#  dense_7 (Dense)             (None, 7)                 119
#
# =================================================================
# Total params: 54,663
# Trainable params: 54,375
# Non-trainable params: 288
# _________________________________________________________________
# Epoch 1/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.5751 - accuracy: 0.3805 - val_loss: 1.5221 - val_accuracy: 0.4155
# Epoch 2/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.3773 - accuracy: 0.4711 - val_loss: 1.4627 - val_accuracy: 0.4441
# Epoch 3/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.3144 - accuracy: 0.4979 - val_loss: 1.3136 - val_accuracy: 0.5053
# Epoch 4/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.2661 - accuracy: 0.5221 - val_loss: 1.3825 - val_accuracy: 0.4708
# Epoch 5/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.2227 - accuracy: 0.5376 - val_loss: 1.4034 - val_accuracy: 0.4558
# Epoch 6/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.1922 - accuracy: 0.5525 - val_loss: 1.2618 - val_accuracy: 0.5256
# Epoch 7/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.1637 - accuracy: 0.5619 - val_loss: 1.2664 - val_accuracy: 0.5249
# Epoch 8/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.1387 - accuracy: 0.5748 - val_loss: 1.3685 - val_accuracy: 0.5071
# Epoch 9/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.1146 - accuracy: 0.5777 - val_loss: 1.2946 - val_accuracy: 0.5154
# Epoch 10/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.0927 - accuracy: 0.5883 - val_loss: 1.2356 - val_accuracy: 0.5458
# Epoch 11/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.0732 - accuracy: 0.5993 - val_loss: 1.2669 - val_accuracy: 0.5406
# Epoch 12/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.0597 - accuracy: 0.6015 - val_loss: 1.3707 - val_accuracy: 0.5054
# Epoch 13/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.0394 - accuracy: 0.6113 - val_loss: 1.2554 - val_accuracy: 0.5389
# Epoch 14/15
# 1615/1615 [==============================] - ETA: 0s - loss: 1.0260 - accuracy: 0.6148Restoring model weights from the end of the best epoch: 10.
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.0260 - accuracy: 0.6148 - val_loss: 1.3824 - val_accuracy: 0.4954
# Epoch 14: early stopping
# Accuracy on test set: 0.550571
# learning_rate  =  0.005
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 46, 46, 64)        640
#
#  batch_normalization_12 (Bat  (None, 46, 46, 64)       256
#  chNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 15, 15, 64)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_9 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  batch_normalization_13 (Bat  (None, 4, 4, 64)         256
#  chNormalization)
#
#  flatten_4 (Flatten)         (None, 1024)              0
#
#  dense_8 (Dense)             (None, 16)                16400
#
#  batch_normalization_14 (Bat  (None, 16)               64
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 16)                0
#
#  dense_9 (Dense)             (None, 7)                 119
#
# =================================================================
# Total params: 54,663
# Trainable params: 54,375
# Non-trainable params: 288
# _________________________________________________________________
# Epoch 1/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.5789 - accuracy: 0.3829 - val_loss: 1.5299 - val_accuracy: 0.4386
# Epoch 2/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.3953 - accuracy: 0.4665 - val_loss: 1.4305 - val_accuracy: 0.4504
# Epoch 3/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.3270 - accuracy: 0.4949 - val_loss: 1.3948 - val_accuracy: 0.4701
# Epoch 4/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.2744 - accuracy: 0.5157 - val_loss: 1.3764 - val_accuracy: 0.4765
# Epoch 5/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.2386 - accuracy: 0.5314 - val_loss: 1.2786 - val_accuracy: 0.5142
# Epoch 6/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.2063 - accuracy: 0.5459 - val_loss: 1.2669 - val_accuracy: 0.5206
# Epoch 7/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.1673 - accuracy: 0.5601 - val_loss: 1.3752 - val_accuracy: 0.4767
# Epoch 8/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.1416 - accuracy: 0.5715 - val_loss: 1.3131 - val_accuracy: 0.5139
# Epoch 9/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.1187 - accuracy: 0.5837 - val_loss: 1.2523 - val_accuracy: 0.5293
# Epoch 10/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.1072 - accuracy: 0.5842 - val_loss: 1.2685 - val_accuracy: 0.5256
# Epoch 11/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.0785 - accuracy: 0.5948 - val_loss: 1.2478 - val_accuracy: 0.5381
# Epoch 12/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.0595 - accuracy: 0.6043 - val_loss: 1.2958 - val_accuracy: 0.5209
# Epoch 13/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.0461 - accuracy: 0.6082 - val_loss: 1.5525 - val_accuracy: 0.4961
# Epoch 14/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.0349 - accuracy: 0.6127 - val_loss: 1.2606 - val_accuracy: 0.5388
# Epoch 15/15
# 1614/1615 [============================>.] - ETA: 0s - loss: 1.0146 - accuracy: 0.6211Restoring model weights from the end of the best epoch: 11.
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.0147 - accuracy: 0.6211 - val_loss: 1.3854 - val_accuracy: 0.5090
# Epoch 15: early stopping
# Accuracy on test set: 0.548342
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 46, 46, 64)        640
#
#  batch_normalization_15 (Bat  (None, 46, 46, 64)       256
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 15, 15, 64)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 13, 13, 64)        36928
#
#  max_pooling2d_11 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  batch_normalization_16 (Bat  (None, 4, 4, 64)         256
#  chNormalization)
#
#  flatten_5 (Flatten)         (None, 1024)              0
#
#  dense_10 (Dense)            (None, 16)                16400
#
#  batch_normalization_17 (Bat  (None, 16)               64
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 16)                0
#
#  dense_11 (Dense)            (None, 7)                 119
#
# =================================================================
# Total params: 54,663
# Trainable params: 54,375
# Non-trainable params: 288
# _________________________________________________________________
# Epoch 1/15
# 1615/1615 [==============================] - 13s 7ms/step - loss: 1.6146 - accuracy: 0.3614 - val_loss: 1.4384 - val_accuracy: 0.4487
# Epoch 2/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.4070 - accuracy: 0.4602 - val_loss: 1.3795 - val_accuracy: 0.4728
# Epoch 3/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.3254 - accuracy: 0.4962 - val_loss: 1.4061 - val_accuracy: 0.4535
# Epoch 4/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.2789 - accuracy: 0.5156 - val_loss: 1.2971 - val_accuracy: 0.5120
# Epoch 5/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.2382 - accuracy: 0.5304 - val_loss: 1.2558 - val_accuracy: 0.5254
# Epoch 6/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.2054 - accuracy: 0.5453 - val_loss: 1.2980 - val_accuracy: 0.5139
# Epoch 7/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.1714 - accuracy: 0.5572 - val_loss: 1.2799 - val_accuracy: 0.5142
# Epoch 8/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.1493 - accuracy: 0.5714 - val_loss: 1.3079 - val_accuracy: 0.5136
# Epoch 9/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.1245 - accuracy: 0.5764 - val_loss: 1.2395 - val_accuracy: 0.5367
# Epoch 10/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.0997 - accuracy: 0.5872 - val_loss: 1.2709 - val_accuracy: 0.5262
# Epoch 11/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.0819 - accuracy: 0.5960 - val_loss: 1.3204 - val_accuracy: 0.5023
# Epoch 12/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.0613 - accuracy: 0.6023 - val_loss: 1.4441 - val_accuracy: 0.4946
# Epoch 13/15
# 1611/1615 [============================>.] - ETA: 0s - loss: 1.0440 - accuracy: 0.6118Restoring model weights from the end of the best epoch: 9.
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.0439 - accuracy: 0.6117 - val_loss: 1.4386 - val_accuracy: 0.4900
# Epoch 13: early stopping
# Accuracy on test set: 0.534968
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 46, 46, 64)        640
#
#  batch_normalization_18 (Bat  (None, 46, 46, 64)       256
#  chNormalization)
#
#  max_pooling2d_12 (MaxPoolin  (None, 15, 15, 64)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 13, 13, 64)        36928
#
#  max_pooling2d_13 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  batch_normalization_19 (Bat  (None, 4, 4, 64)         256
#  chNormalization)
#
#  flatten_6 (Flatten)         (None, 1024)              0
#
#  dense_12 (Dense)            (None, 16)                16400
#
#  batch_normalization_20 (Bat  (None, 16)               64
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 16)                0
#
#  dense_13 (Dense)            (None, 7)                 119
#
# =================================================================
# Total params: 54,663
# Trainable params: 54,375
# Non-trainable params: 288
# _________________________________________________________________
# Epoch 1/15
# 1615/1615 [==============================] - 13s 7ms/step - loss: 1.5963 - accuracy: 0.3783 - val_loss: 1.6292 - val_accuracy: 0.3561
# Epoch 2/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.3972 - accuracy: 0.4664 - val_loss: 1.3729 - val_accuracy: 0.4731
# Epoch 3/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.3250 - accuracy: 0.4984 - val_loss: 1.4208 - val_accuracy: 0.4465
# Epoch 4/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.2623 - accuracy: 0.5221 - val_loss: 1.3625 - val_accuracy: 0.4740
# Epoch 5/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.2333 - accuracy: 0.5315 - val_loss: 1.3873 - val_accuracy: 0.4657
# Epoch 6/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.1925 - accuracy: 0.5492 - val_loss: 1.3236 - val_accuracy: 0.5000
# Epoch 7/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.1741 - accuracy: 0.5554 - val_loss: 1.3340 - val_accuracy: 0.4928
# Epoch 8/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.1443 - accuracy: 0.5701 - val_loss: 1.3211 - val_accuracy: 0.5027
# Epoch 9/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.1207 - accuracy: 0.5793 - val_loss: 1.2494 - val_accuracy: 0.5315
# Epoch 10/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.1066 - accuracy: 0.5856 - val_loss: 1.7025 - val_accuracy: 0.4443
# Epoch 11/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.0804 - accuracy: 0.5942 - val_loss: 1.2607 - val_accuracy: 0.5306
# Epoch 12/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.0633 - accuracy: 0.6018 - val_loss: 1.3245 - val_accuracy: 0.5166
# Epoch 13/15
# 1609/1615 [============================>.] - ETA: 0s - loss: 1.0581 - accuracy: 0.6038Restoring model weights from the end of the best epoch: 9.
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.0581 - accuracy: 0.6038 - val_loss: 1.3032 - val_accuracy: 0.5186
# Epoch 13: early stopping
# Accuracy on test set: 0.550014
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_14 (Conv2D)          (None, 46, 46, 64)        640
#
#  batch_normalization_21 (Bat  (None, 46, 46, 64)       256
#  chNormalization)
#
#  max_pooling2d_14 (MaxPoolin  (None, 15, 15, 64)       0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 13, 13, 64)        36928
#
#  max_pooling2d_15 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  batch_normalization_22 (Bat  (None, 4, 4, 64)         256
#  chNormalization)
#
#  flatten_7 (Flatten)         (None, 1024)              0
#
#  dense_14 (Dense)            (None, 16)                16400
#
#  batch_normalization_23 (Bat  (None, 16)               64
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 16)                0
#
#  dense_15 (Dense)            (None, 7)                 119
#
# =================================================================
# Total params: 54,663
# Trainable params: 54,375
# Non-trainable params: 288
# _________________________________________________________________
# Epoch 1/15
# 1615/1615 [==============================] - 13s 7ms/step - loss: 1.5801 - accuracy: 0.3797 - val_loss: 1.4283 - val_accuracy: 0.4485
# Epoch 2/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.3942 - accuracy: 0.4666 - val_loss: 1.4139 - val_accuracy: 0.4532
# Epoch 3/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.3277 - accuracy: 0.4962 - val_loss: 1.6086 - val_accuracy: 0.4069
# Epoch 4/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.2725 - accuracy: 0.5185 - val_loss: 1.2727 - val_accuracy: 0.5209
# Epoch 5/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.2356 - accuracy: 0.5323 - val_loss: 1.4983 - val_accuracy: 0.4605
# Epoch 6/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.2058 - accuracy: 0.5436 - val_loss: 1.4859 - val_accuracy: 0.4292
# Epoch 7/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.1806 - accuracy: 0.5585 - val_loss: 1.3463 - val_accuracy: 0.5005
# Epoch 8/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.1512 - accuracy: 0.5698 - val_loss: 1.2644 - val_accuracy: 0.5168
# Epoch 9/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.1252 - accuracy: 0.5788 - val_loss: 1.3204 - val_accuracy: 0.5036
# Epoch 10/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.1090 - accuracy: 0.5841 - val_loss: 1.4322 - val_accuracy: 0.5093
# Epoch 11/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.0865 - accuracy: 0.5935 - val_loss: 1.2651 - val_accuracy: 0.5327
# Epoch 12/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.0659 - accuracy: 0.6009 - val_loss: 1.2505 - val_accuracy: 0.5324
# Epoch 13/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.0492 - accuracy: 0.6074 - val_loss: 1.4911 - val_accuracy: 0.5103
# Epoch 14/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.0328 - accuracy: 0.6160 - val_loss: 1.4274 - val_accuracy: 0.4761
# Epoch 15/15
# 1615/1615 [==============================] - 11s 7ms/step - loss: 1.0225 - accuracy: 0.6220 - val_loss: 1.3573 - val_accuracy: 0.5220
# Accuracy on test set: 0.520201
# learning_rate  =  0.007
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 46, 46, 64)        640
#
#  batch_normalization_24 (Bat  (None, 46, 46, 64)       256
#  chNormalization)
#
#  max_pooling2d_16 (MaxPoolin  (None, 15, 15, 64)       0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 13, 13, 64)        36928
#
#  max_pooling2d_17 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  batch_normalization_25 (Bat  (None, 4, 4, 64)         256
#  chNormalization)
#
#  flatten_8 (Flatten)         (None, 1024)              0
#
#  dense_16 (Dense)            (None, 16)                16400
#
#  batch_normalization_26 (Bat  (None, 16)               64
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 16)                0
#
#  dense_17 (Dense)            (None, 7)                 119
#
# =================================================================
# Total params: 54,663
# Trainable params: 54,375
# Non-trainable params: 288
# _________________________________________________________________
# Epoch 1/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.6050 - accuracy: 0.3728 - val_loss: 1.5470 - val_accuracy: 0.3948
# Epoch 2/15
# 1615/1615 [==============================] - 12s 7ms/step - loss: 1.3984 - accuracy: 0.4625 - val_loss: 1.4010 - val_accuracy: 0.4632
# Epoch 3/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.3281 - accuracy: 0.4921 - val_loss: 1.3649 - val_accuracy: 0.4851
# Epoch 4/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.2660 - accuracy: 0.5191 - val_loss: 1.5480 - val_accuracy: 0.3749
# Epoch 5/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.2292 - accuracy: 0.5329 - val_loss: 1.3833 - val_accuracy: 0.4935
# Epoch 6/15
# 1615/1615 [==============================] - 12s 8ms/step - loss: 1.1933 - accuracy: 0.5482 - val_loss: 1.2902 - val_accuracy: 0.5176
# Epoch 7/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.1645 - accuracy: 0.5614 - val_loss: 1.2405 - val_accuracy: 0.5346
# Epoch 8/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.1350 - accuracy: 0.5764 - val_loss: 1.2957 - val_accuracy: 0.5108
# Epoch 9/15
# 1615/1615 [==============================] - 12s 8ms/step - loss: 1.1155 - accuracy: 0.5820 - val_loss: 1.4143 - val_accuracy: 0.4852
# Epoch 10/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.0955 - accuracy: 0.5912 - val_loss: 1.3263 - val_accuracy: 0.5100
# Epoch 11/15
# 1614/1615 [============================>.] - ETA: 0s - loss: 1.0782 - accuracy: 0.5966Restoring model weights from the end of the best epoch: 7.
# 1615/1615 [==============================] - 12s 8ms/step - loss: 1.0782 - accuracy: 0.5966 - val_loss: 1.3216 - val_accuracy: 0.5221
# Epoch 11: early stopping
# Accuracy on test set: 0.521594
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 46, 46, 64)        640
#
#  batch_normalization_27 (Bat  (None, 46, 46, 64)       256
#  chNormalization)
#
#  max_pooling2d_18 (MaxPoolin  (None, 15, 15, 64)       0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 13, 13, 64)        36928
#
#  max_pooling2d_19 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  batch_normalization_28 (Bat  (None, 4, 4, 64)         256
#  chNormalization)
#
#  flatten_9 (Flatten)         (None, 1024)              0
#
#  dense_18 (Dense)            (None, 16)                16400
#
#  batch_normalization_29 (Bat  (None, 16)               64
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 16)                0
#
#  dense_19 (Dense)            (None, 7)                 119
#
# =================================================================
# Total params: 54,663
# Trainable params: 54,375
# Non-trainable params: 288
# _________________________________________________________________
# Epoch 1/15
# 1615/1615 [==============================] - 14s 8ms/step - loss: 1.5702 - accuracy: 0.3876 - val_loss: 1.7387 - val_accuracy: 0.2827
# Epoch 2/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.3906 - accuracy: 0.4703 - val_loss: 1.9989 - val_accuracy: 0.3711
# Epoch 3/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.3255 - accuracy: 0.4959 - val_loss: 1.5658 - val_accuracy: 0.4030
# Epoch 4/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.2661 - accuracy: 0.5189 - val_loss: 1.2832 - val_accuracy: 0.5172
# Epoch 5/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.2246 - accuracy: 0.5356 - val_loss: 1.2864 - val_accuracy: 0.5121
# Epoch 6/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.1997 - accuracy: 0.5440 - val_loss: 1.3090 - val_accuracy: 0.5092
# Epoch 7/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.1688 - accuracy: 0.5577 - val_loss: 1.3337 - val_accuracy: 0.5058
# Epoch 8/15
# 1613/1615 [============================>.] - ETA: 0s - loss: 1.1349 - accuracy: 0.5748Restoring model weights from the end of the best epoch: 4.
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.1355 - accuracy: 0.5748 - val_loss: 1.3156 - val_accuracy: 0.4949
# Epoch 8: early stopping
# Accuracy on test set: 0.52243
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 46, 46, 64)        640
#
#  batch_normalization_30 (Bat  (None, 46, 46, 64)       256
#  chNormalization)
#
#  max_pooling2d_20 (MaxPoolin  (None, 15, 15, 64)       0
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 13, 13, 64)        36928
#
#  max_pooling2d_21 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  batch_normalization_31 (Bat  (None, 4, 4, 64)         256
#  chNormalization)
#
#  flatten_10 (Flatten)        (None, 1024)              0
#
#  dense_20 (Dense)            (None, 16)                16400
#
#  batch_normalization_32 (Bat  (None, 16)               64
#  chNormalization)
#
#  dropout_10 (Dropout)        (None, 16)                0
#
#  dense_21 (Dense)            (None, 7)                 119
#
# =================================================================
# Total params: 54,663
# Trainable params: 54,375
# Non-trainable params: 288
# _________________________________________________________________
# Epoch 1/15
# 1615/1615 [==============================] - 14s 8ms/step - loss: 1.5781 - accuracy: 0.3767 - val_loss: 1.4592 - val_accuracy: 0.4318
# Epoch 2/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.3979 - accuracy: 0.4635 - val_loss: 1.5383 - val_accuracy: 0.4007
# Epoch 3/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.3345 - accuracy: 0.4921 - val_loss: 1.3654 - val_accuracy: 0.4802
# Epoch 4/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.2832 - accuracy: 0.5116 - val_loss: 1.5024 - val_accuracy: 0.4450
# Epoch 5/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.2447 - accuracy: 0.5295 - val_loss: 1.3873 - val_accuracy: 0.4797
# Epoch 6/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.2106 - accuracy: 0.5447 - val_loss: 1.2855 - val_accuracy: 0.5100
# Epoch 7/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.1839 - accuracy: 0.5582 - val_loss: 1.4403 - val_accuracy: 0.4855
# Epoch 8/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.1577 - accuracy: 0.5684 - val_loss: 1.2719 - val_accuracy: 0.5218
# Epoch 9/15
# 1615/1615 [==============================] - 12s 8ms/step - loss: 1.1345 - accuracy: 0.5769 - val_loss: 1.4431 - val_accuracy: 0.4948
# Epoch 10/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.1183 - accuracy: 0.5843 - val_loss: 1.3142 - val_accuracy: 0.5135
# Epoch 11/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.0969 - accuracy: 0.5921 - val_loss: 1.3891 - val_accuracy: 0.4881
# Epoch 12/15
# 1611/1615 [============================>.] - ETA: 0s - loss: 1.0757 - accuracy: 0.6024Restoring model weights from the end of the best epoch: 8.
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.0753 - accuracy: 0.6025 - val_loss: 1.3037 - val_accuracy: 0.5218
# Epoch 12: early stopping
# Accuracy on test set: 0.522987
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_22 (Conv2D)          (None, 46, 46, 64)        640
#
#  batch_normalization_33 (Bat  (None, 46, 46, 64)       256
#  chNormalization)
#
#  max_pooling2d_22 (MaxPoolin  (None, 15, 15, 64)       0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 13, 13, 64)        36928
#
#  max_pooling2d_23 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  batch_normalization_34 (Bat  (None, 4, 4, 64)         256
#  chNormalization)
#
#  flatten_11 (Flatten)        (None, 1024)              0
#
# ...
# Epoch 8/15
# 1614/1615 [============================>.] - ETA: 0s - loss: 1.1579 - accuracy: 0.5659Restoring model weights from the end of the best epoch: 4.
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.1576 - accuracy: 0.5659 - val_loss: 1.5050 - val_accuracy: 0.4584
# Epoch 8: early stopping
# Accuracy on test set: 0.494288
# learning_rate  =  0.05
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_32 (Conv2D)          (None, 46, 46, 64)        640
#
#  batch_normalization_48 (Bat  (None, 46, 46, 64)       256
#  chNormalization)
#
#  max_pooling2d_32 (MaxPoolin  (None, 15, 15, 64)       0
#  g2D)
#
#  conv2d_33 (Conv2D)          (None, 13, 13, 64)        36928
#
#  max_pooling2d_33 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  batch_normalization_49 (Bat  (None, 4, 4, 64)         256
#  chNormalization)
#
#  flatten_16 (Flatten)        (None, 1024)              0
#
#  dense_32 (Dense)            (None, 16)                16400
#
#  batch_normalization_50 (Bat  (None, 16)               64
#  chNormalization)
#
#  dropout_16 (Dropout)        (None, 16)                0
#
#  dense_33 (Dense)            (None, 7)                 119
#
# =================================================================
# Total params: 54,663
# Trainable params: 54,375
# Non-trainable params: 288
# _________________________________________________________________
# Epoch 1/15
# 1615/1615 [==============================] - 15s 9ms/step - loss: 1.5972 - accuracy: 0.3739 - val_loss: 1.6220 - val_accuracy: 0.3534
# Epoch 2/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.4004 - accuracy: 0.4628 - val_loss: 1.4052 - val_accuracy: 0.4599
# Epoch 3/15
# 1615/1615 [==============================] - 14s 9ms/step - loss: 1.3411 - accuracy: 0.4909 - val_loss: 1.4693 - val_accuracy: 0.4443
# Epoch 4/15
# 1615/1615 [==============================] - 14s 8ms/step - loss: 1.2933 - accuracy: 0.5104 - val_loss: 1.4469 - val_accuracy: 0.4572
# Epoch 5/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.2509 - accuracy: 0.5243 - val_loss: 1.3021 - val_accuracy: 0.4971
# Epoch 6/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.2123 - accuracy: 0.5402 - val_loss: 1.2993 - val_accuracy: 0.5085
# Epoch 7/15
# 1615/1615 [==============================] - 14s 8ms/step - loss: 1.1860 - accuracy: 0.5529 - val_loss: 1.3373 - val_accuracy: 0.5064
# Epoch 8/15
# 1615/1615 [==============================] - 14s 8ms/step - loss: 1.1650 - accuracy: 0.5582 - val_loss: 1.4711 - val_accuracy: 0.4568
# Epoch 9/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.1343 - accuracy: 0.5767 - val_loss: 1.3767 - val_accuracy: 0.5022
# Epoch 10/15
# 1613/1615 [============================>.] - ETA: 0s - loss: 1.1112 - accuracy: 0.5820Restoring model weights from the end of the best epoch: 6.
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.1111 - accuracy: 0.5820 - val_loss: 1.3012 - val_accuracy: 0.5108
# Epoch 10: early stopping
# Accuracy on test set: 0.513235
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_34 (Conv2D)          (None, 46, 46, 64)        640
#
#  batch_normalization_51 (Bat  (None, 46, 46, 64)       256
#  chNormalization)
#
#  max_pooling2d_34 (MaxPoolin  (None, 15, 15, 64)       0
#  g2D)
#
#  conv2d_35 (Conv2D)          (None, 13, 13, 64)        36928
#
#  max_pooling2d_35 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  batch_normalization_52 (Bat  (None, 4, 4, 64)         256
#  chNormalization)
#
#  flatten_17 (Flatten)        (None, 1024)              0
#
#  dense_34 (Dense)            (None, 16)                16400
#
#  batch_normalization_53 (Bat  (None, 16)               64
#  chNormalization)
#
#  dropout_17 (Dropout)        (None, 16)                0
#
#  dense_35 (Dense)            (None, 7)                 119
#
# =================================================================
# Total params: 54,663
# Trainable params: 54,375
# Non-trainable params: 288
# _________________________________________________________________
# Epoch 1/15
# 1615/1615 [==============================] - 14s 9ms/step - loss: 1.5795 - accuracy: 0.3829 - val_loss: 1.5864 - val_accuracy: 0.3953
# Epoch 2/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.4051 - accuracy: 0.4596 - val_loss: 1.3691 - val_accuracy: 0.4728
# Epoch 3/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.3309 - accuracy: 0.4916 - val_loss: 1.4732 - val_accuracy: 0.4198
# Epoch 4/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.2735 - accuracy: 0.5145 - val_loss: 1.3051 - val_accuracy: 0.4986
# Epoch 5/15
# 1615/1615 [==============================] - 14s 9ms/step - loss: 1.2356 - accuracy: 0.5317 - val_loss: 1.3113 - val_accuracy: 0.5007
# Epoch 6/15
# 1615/1615 [==============================] - 14s 8ms/step - loss: 1.2039 - accuracy: 0.5476 - val_loss: 1.3383 - val_accuracy: 0.4904
# Epoch 7/15
# 1615/1615 [==============================] - 14s 8ms/step - loss: 1.1745 - accuracy: 0.5557 - val_loss: 1.2682 - val_accuracy: 0.5253
# Epoch 8/15
# 1615/1615 [==============================] - 14s 9ms/step - loss: 1.1470 - accuracy: 0.5674 - val_loss: 1.3369 - val_accuracy: 0.5131
# Epoch 9/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.1182 - accuracy: 0.5802 - val_loss: 1.2853 - val_accuracy: 0.5199
# Epoch 10/15
# 1615/1615 [==============================] - 14s 8ms/step - loss: 1.0942 - accuracy: 0.5874 - val_loss: 1.2937 - val_accuracy: 0.5215
# Epoch 11/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.0714 - accuracy: 0.5974 - val_loss: 1.2514 - val_accuracy: 0.5404
# Epoch 12/15
# 1615/1615 [==============================] - 14s 8ms/step - loss: 1.0653 - accuracy: 0.6017 - val_loss: 1.3382 - val_accuracy: 0.5086
# Epoch 13/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.0380 - accuracy: 0.6065 - val_loss: 1.5613 - val_accuracy: 0.4734
# Epoch 14/15
# 1615/1615 [==============================] - 14s 9ms/step - loss: 1.0290 - accuracy: 0.6140 - val_loss: 1.4844 - val_accuracy: 0.4971
# Epoch 15/15
# 1615/1615 [==============================] - ETA: 0s - loss: 1.0151 - accuracy: 0.6196Restoring model weights from the end of the best epoch: 11.
# 1615/1615 [==============================] - 14s 9ms/step - loss: 1.0151 - accuracy: 0.6196 - val_loss: 1.3723 - val_accuracy: 0.5243
# Epoch 15: early stopping
# Accuracy on test set: 0.527166
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_36 (Conv2D)          (None, 46, 46, 64)        640
#
#  batch_normalization_54 (Bat  (None, 46, 46, 64)       256
#  chNormalization)
#
#  max_pooling2d_36 (MaxPoolin  (None, 15, 15, 64)       0
#  g2D)
#
#  conv2d_37 (Conv2D)          (None, 13, 13, 64)        36928
#
#  max_pooling2d_37 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  batch_normalization_55 (Bat  (None, 4, 4, 64)         256
#  chNormalization)
#
#  flatten_18 (Flatten)        (None, 1024)              0
#
#  dense_36 (Dense)            (None, 16)                16400
#
#  batch_normalization_56 (Bat  (None, 16)               64
#  chNormalization)
#
#  dropout_18 (Dropout)        (None, 16)                0
#
#  dense_37 (Dense)            (None, 7)                 119
#
# =================================================================
# Total params: 54,663
# Trainable params: 54,375
# Non-trainable params: 288
# _________________________________________________________________
# Epoch 1/15
# 1615/1615 [==============================] - 14s 8ms/step - loss: 1.5794 - accuracy: 0.3826 - val_loss: 1.5778 - val_accuracy: 0.3846
# Epoch 2/15
# 1615/1615 [==============================] - 14s 8ms/step - loss: 1.3978 - accuracy: 0.4624 - val_loss: 1.4517 - val_accuracy: 0.4233
# Epoch 3/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.3150 - accuracy: 0.4965 - val_loss: 1.4130 - val_accuracy: 0.4614
# Epoch 4/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.2682 - accuracy: 0.5196 - val_loss: 1.3389 - val_accuracy: 0.4803
# Epoch 5/15
# 1615/1615 [==============================] - 14s 8ms/step - loss: 1.2273 - accuracy: 0.5349 - val_loss: 1.2529 - val_accuracy: 0.5254
# Epoch 6/15
# 1615/1615 [==============================] - 14s 9ms/step - loss: 1.1901 - accuracy: 0.5503 - val_loss: 1.3908 - val_accuracy: 0.4907
# Epoch 7/15
# 1615/1615 [==============================] - 13s 8ms/step - loss: 1.1563 - accuracy: 0.5666 - val_loss: 1.3401 - val_accuracy: 0.4772
# Epoch 8/15
# 1615/1615 [==============================] - 14s 8ms/step - loss: 1.1384 - accuracy: 0.5726 - val_loss: 1.2837 - val_accuracy: 0.5144
# Epoch 9/15
# 1612/1615 [============================>.] - ETA: 0s - loss: 1.1223 - accuracy: 0.5775Restoring model weights from the end of the best epoch: 5.
# 1615/1615 [==============================] - 14s 9ms/step - loss: 1.1223 - accuracy: 0.5774 - val_loss: 1.7446 - val_accuracy: 0.4092
# Epoch 9: early stopping
# Accuracy on test set: 0.521872
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_38 (Conv2D)          (None, 46, 46, 64)        640
#
#  batch_normalization_57 (Bat  (None, 46, 46, 64)       256
#  chNormalization)
#
#  max_pooling2d_38 (MaxPoolin  (None, 15, 15, 64)       0
#  g2D)
#
#  conv2d_39 (Conv2D)          (None, 13, 13, 64)        36928
#
#  max_pooling2d_39 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  batch_normalization_58 (Bat  (None, 4, 4, 64)         256
#  chNormalization)
#
#  flatten_19 (Flatten)        (None, 1024)              0
#
#  dense_38 (Dense)            (None, 16)                16400
#
#  batch_normalization_59 (Bat  (None, 16)               64
#  chNormalization)
#
#  dropout_19 (Dropout)        (None, 16)                0
#
#  dense_39 (Dense)            (None, 7)                 119
#
# =================================================================
# Total params: 54,663
# Trainable params: 54,375
# Non-trainable params: 288
# _________________________________________________________________
# Epoch 1/15
# 1615/1615 [==============================] - 14s 8ms/step - loss: 1.5804 - accuracy: 0.3794 - val_loss: 2.3304 - val_accuracy: 0.2939
# Epoch 2/15
# 1615/1615 [==============================] - 14s 9ms/step - loss: 1.4001 - accuracy: 0.4621 - val_loss: 1.5609 - val_accuracy: 0.4158
# Epoch 3/15
# 1615/1615 [==============================] - 14s 9ms/step - loss: 1.3253 - accuracy: 0.4969 - val_loss: 1.3154 - val_accuracy: 0.4963
# Epoch 4/15
# 1615/1615 [==============================] - 14s 9ms/step - loss: 1.2750 - accuracy: 0.5178 - val_loss: 1.3389 - val_accuracy: 0.4827
# Epoch 5/15
# 1615/1615 [==============================] - 14s 9ms/step - loss: 1.2359 - accuracy: 0.5328 - val_loss: 1.4112 - val_accuracy: 0.4656
# Epoch 6/15
# 1615/1615 [==============================] - 14s 9ms/step - loss: 1.1989 - accuracy: 0.5492 - val_loss: 1.3479 - val_accuracy: 0.4928
# Epoch 7/15
# 1613/1615 [============================>.] - ETA: 0s - loss: 1.1712 - accuracy: 0.5582Restoring model weights from the end of the best epoch: 3.
# 1615/1615 [==============================] - 14s 8ms/step - loss: 1.1709 - accuracy: 0.5584 - val_loss: 1.3259 - val_accuracy: 0.4938
# Epoch 7: early stopping
# Accuracy on test set: 0.485651

# %%
# run_experiment('pool_size',pool_sizes)

# %%
# run_experiment('filters1',filter_sizes)

# %%
# run_experiment('filters2',filter_sizes)

# %%
# printing 5 random images with their labels and predictions

predictions = model.predict(X_test, workers=12)
max_predictions = np.argmax(predictions, axis=1)
random_int = np.random.randint(low=0, high=3590-5)

fig = plt.figure(figsize=(18, 5))

for i, prediction in enumerate(max_predictions[random_int:random_int+5]):
    ax = plt.subplot(1, 5, i+1)
    ax.imshow(X_test[random_int+i], cmap='gray')
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title(f'label={emotion_dict[df_test.emotion.iloc[random_int+i]]}, predicted={emotion_dict[prediction]}')
plt.tight_layout()
# Out:
# 113/113 [==============================] - 3s 25ms/step
